# %% [markdown]
# # Hangman
#
# # Step 1 :-
#
# Your goal is build a hangman game using everything you have learnt about Python prgoramming.
#
# The project is split into 5 major steps. In each step, there will be multiple TODOs. Your goal is too go through each todo in order are complete them.

# %%
word_list = ["aardvark","baboon","camel"]

# TODO -1 :- Randomly choose a word from the word_list and assign it to a variable called choosen_word. Then print it.

import random 
chosen_word = random.choice(word_list)
print(chosen_word)

#TODO -2 :- Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.

guess = input("guess a letter :").lower()
print(guess)

# TODO -3 :- Ask the user to guess a letter and assign there one of the letter in the chosen _word. print "Right " if it.

for letter in chosen_word:
    if letter == guess:
        print("Right")
    else:
        print("Wrong")
# Out:
# camel
# guess a letter : c
# c
# Right
# Wrong
# Wrong
# Wrong
# Wrong

# %% [markdown]
# # Step 2
# #TODO-1
#
#       (1). Create an empty String called placeholder.
#       (2). For each letter in the chosen_word, add a _to placeholder.
#       (3). So if the chosen_word was "apple",placeholder should be _ _ _ _ _
#       with5 "_" repersening each letter to guess.
#
# #TODO-2
#
#      (1). Creste an empty string called "display ".
#      (2).Loop through each letter in the chosen_word
#      (3).If the letter at the position matches guess then reveal that letter inthe display at that position.
#      (4).e.g if the user guesses "p" and the chosen word was "apple", then display should be   _ p p _ _ .
#      (5).print display and you should see the guessed letter in the correct position.
#      (6).But every letter that is not match is represented with a "_".

# %%
import random 
word_list = ["aardvark","baboon","camel"]

chosen_word = random.choice(word_list)
print(chosen_word)

# TODO-1 : Create a "placeholder" with the same number of blank as the chosen_word place

placeholder = ""
word_length = len(chosen_word)
for position in range (1,6):
    placeholder = placeholder + "-"
print(placeholder)

# TODO-2 :- Create a "display" that puts the guess letter in the right position and _in the rest of the Strings.

display = ""
for letter in chosen_word:
    if letter  == guess:
        display = display + letter 
    else:
        display = display + "_"
        
print(display)
# Out:
# baboon
# -----
# ______

# %% [markdown]
# # Step-3
#   (1).Update the for loop so that previous guesses are added to the display string.
#   (2).At the moment, when the user makes a new guess, the previous guess get replaced by a "_". We need to fix that by updating the for loop.

# %%
import random

# 1. Word list
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
prin.t(chosen_word)   # (for testing)

# 2Create placeholder
word_length = len(chosen_word)
display = []
for _ in range(word_length):
    display.append("_")

print(display)
# TODO-1:- Use a while loop to let the user guess again.
game_over = False
while not game_over:
    guess = input("Guess a letter: ").lower()

# TODO-2:- Change the for loop so that you keep the previous correcterletter. 

    # Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter

    print(display)

    # Win condition
    if "_" not in display:
        game_over = True
        print(" You win!")
# Out:
# aardvark
# ['_', '_', '_', '_', '_', '_', '_', '_']
# Guess a letter:  a
# ['a', 'a', '_', '_', '_', 'a', '_', '_']
# Guess a letter:  r
# ['a', 'a', 'r', '_', '_', 'a', 'r', '_']
# Guess a letter:  a
# ['a', 'a', 'r', '_', '_', 'a', 'r', '_']
# Guess a letter:  v
# ['a', 'a', 'r', '_', 'v', 'a', 'r', '_']
# Guess a letter:  a
# ['a', 'a', 'r', '_', 'v', 'a', 'r', '_']
# Guess a letter:  k
# ['a', 'a', 'r', '_', 'v', 'a', 'r', 'k']
# Guess a letter:  d
# ['a', 'a', 'r', 'd', 'v', 'a', 'r', 'k']
#  You win!

# %% [markdown]
# # Step 4
#
# This is a task description file. it's content will be displayed to a learner in the Task Description window.
#
# It supports both Markdowm and HTML. To toggle the format,
# you can rename task.md to task.html, or vice versa. The default task description format can be changed in Preferences I Tools I
# Education, but this will not affect any existing task
# description files.
#
# The following features are availiable in task.md/task.html which are specific to the jetBrains Academy plugin:
#
#         1.Hints can be added anywhare in the task text. Type "hint" and press Tab. Hints should be added to an empty line in the task text. In hints you can use both HTML and Markdown.
#
#
# #Hint
#
# Text of your hint
#
#      1.you may need to refer your learners to a particular lesson, task , or file. To achive this , you can use the in link . specify the path using the [

# %%
word_list = ["Shivam","Nisha","Shisha"]

#TODO-1 :- Create a variable called 'lives' to keep track  of the
# set 'lives' to equal 6.

chosen_word = random.choice(word_list)
print(chosen_word)

placeholder = ""
word_length = len(chosen_word)
for position in range(word_length):
    placeholder = placeholder + "_"
print(placeholder)

game over = False
