# %% [markdown]
# # A
# # Rondom module
#
# In Python, the random module is used to generate random (unpredictable) values.
#
# Definition :-
# Random module means:- It helps us to pick random numbers or random items from a list.
#
# #Important:-
#
#               import random
#
# #Why we use random module ?
#
# -We use it when we need:
# Random numbers 🎲
# Random choice (like game, lottery, password, etc.)
# Shuffle data
#
#         Their are three main Rondom module method:
#
#         (i). Python Random randint() method.
#            :-Return a number between 5 and 10 (both included):
#
#            import random
#            print(random.randint(5,10))
#
#            (ii). returns number between 3(included) and 9(not included)
#
#            print(random.randrange(3,9))
#
#            (iii)Python Random choice() Method
#
#            Return a random element from a list:
#            l= ["apple","banana","cherry"]
#            print(random.choice(l))

# %% [markdown]
# #Computer are not random, because they are built with circuits and switches. But randomness is very important when building software, especially games. it would be really boring if every move in a video game was per-determined.
#
# So, some computer scientists invented pseudorandom number generators. e.g.
#
# https://docs.python.org/3/library/random.html

# %%
from IPython.display import HTML, display

display(HTML('<a href="https://docs.python.org/3/library/random.html">Random | Python Docs</a>'))
# Out:
# <a href="https://docs.python.org/3/library/random.html">Random | Python Docs</a>
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # The Random module in Python
#
# Read the docs here:

# %%
url = "https://www.w3schools.com/python/module_random.asp"
print(url)
# Out:
# https://www.w3schools.com/python/module_random.asp

# %%
from IPython.display import HTML, display

display(HTML('<a href="https://www.w3schools.com/python/module_random.asp">Random  module | W3school</a>'))
# Out:
# <a href="https://www.w3schools.com/python/module_random.asp">Random  module | W3school</a>

# %% [markdown]
# NOTE :-I am providing the link because it is not practical to memorize every piece of code or function. A programmer is not required to remember everything; rather, they need to understand the code in order to apply it effectively in real-world scenarios. Therefore, the link is included so that if any function or concept is forgotten, it can be easily referred to for clarification.

# %% [markdown]
# # 1.random.randint() function.

# %%
# code
import random
random_integer = random.randint(1, 10)
print(random_integer)
# Out:
# 3

# %% [markdown]
# # 2.random.randrange() function

# %%
var =random.randrange(2,8)
print(var)
# Out:
# 7

# %% [markdown]
# # 3.random.random()

# %%
random_number_0_to_1 = random.random()
print(random_number_0_to_1)
# Out:
# 0.8569183575762401

# %% [markdown]
# #NOTE random.random() :-
# random.random() generates a random floating-point number
# The number is greater than or equal to 0
# The number is less than 1
#
#            0.0 ≤ number < 1.0

# %% [markdown]
# # 4.random.uniform()
# :-random.uniform(a, b) generates a random floating-point (decimal) number between a and b.
#
#       a → lower limit
#       b → upper limit
#       The result can be any decimal value between them.
#
#       #code
#       a ≤ number ≤ b

# %%
random_float =random.uniform(1,10)
print(random_float)
# Out:
# 3.1791547066054138

# %% [raw]
# OR

# %%
random_float1 =random.random() *10
print(random_float1)
# Out:
# 7.140374309575499

# %% [markdown]
# # Note :-
# Create a coin flip program using what you have learnt about randomisation in Python. it should randomly print "Heads" or "Tails" everytime it is run.

# %%
import random

print("Welcome to the game")
# print(input("Enter the number")) # this is optional line of code. 
random_heads_or_tails = random.randint(0, 1)

if random_heads_or_tails == 0:
    print("Heads")
else:
    print("Tails")
# Out:
# Welcome to the game
# Tails

# %% [markdown]
# # B
# # (Data structure)
# #list
#
# A list in Python is a data structure used to store and organize multiple items in a single variable. It can hold different types of data and is ordered and mutable.
#
# A list in Python is both a data type and a data structure, but the correct and commonly accepted answer is:
# List is a data type in Python.
#
#         fruits= [item1, item2]

# %%
states_of_america =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
print(states_of_america)
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia']

# %%
#index 
states_of_america1 =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
print(states_of_america1[1])
# Out:
# Alaska

# %% [markdown]
# # 1 .append()

# %%
#append() adds a value to the last position of a list.
states_of_america2 =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
states_of_america2.append("New jersey")
print(states_of_america2)
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'New jersey']

# %%
from IPython.display import HTML, display

display(HTML('<a href="https://docs.python.org/3/tutorial/datastructures.html"> List | Python Docs</a>'))
# Out:
# <a href="https://docs.python.org/3/tutorial/datastructures.html"> List | Python Docs</a>

# %% [markdown]
# #Note :-n this link, there are many functions available such as append(), extend(), insert(), and many more.
#
#       List | Python Docs

# %% [markdown]
# # 2 .extend()

# %%
states_of_america3 =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
states_of_america3.extend(["New jersey","Maine","Maryland"])
print(states_of_america3)
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'New jersey', 'Maine', 'Maryland']

# %% [markdown]
# # C.Who will pay the bill?

# %%
import random
friends = ["nisha","richa","muskan","neha","nikita","megha"]
print(random.choice(friends)) # when you executed the code each time the name will be change.
# Out:
# muskan

# %%
# 2nd Option
import random

friends1 = ["nisha", "richa", "muskan", "neha", "nikita", "megha"]

two_friends = random.sample(friends1, 2)
print(two_friends)
# Out:
# ['megha', 'nikita']

# %% [markdown]
# # IndexErrors and Working with Nested List

# %% [markdown]
# # 1.IndexError
#
# #Length of List
#
# you can get the lenght of a list(number of items in the list) or the lenght of a string (number characters in the string) by using the len() function.

# %%
states_of_america =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
num_of_states = len(states_of_america) #the United States has 50 states.
print(states_of_america[num_of_state])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 3
#       1 states_of_america =["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia"]
#       2 num_of_states = len(states_of_america) #the United States has 50 states.
# ----> 3 print(states_of_america[num_of_state])
#
# NameError: name 'num_of_state' is not defined

# %%
states_of_america = [
    "Alabama","Alaska","Arizona","Arkansas","California",
    "Colorado","Connecticut","Delaware","Florida","Georgia"
]

num_of_states = len(states_of_america)  # total number of states
print(states_of_america[num_of_states - 1])  # -1 because index starts from 0
# Out:
# Georgia

# %% [markdown]
# # project
#
# ROCK PAPER SCISSORS:-I am going to build a Rock, Paper, and Scissors game. To create this game, I will use the concepts of randomization and lists that I have learned.

# %% [markdown]
# # 1
# use this statement :-  print(f"Computer chose: {computer_choice}")

# %%
import random

# Ask user for input and convert it to int
user_choice = int(input("What do you want to choose? Type 0 for Rock, 1 for Paper or 2 for Scissors: "))

# Computer choice
computer_choice = random.randint(0, 2)
print(f"Computer chose: {computer_choice}")

# Check for invalid input
if user_choice < 0 or user_choice > 2:
    print("You typed an invalid number. You lose!")

elif user_choice == 0 and computer_choice == 2:
    print("You win!")

elif user_choice == 2 and computer_choice == 0:
    print("You lose!")

elif computer_choice > user_choice:
    print("You lose!")

elif user_choice > computer_choice:
    print("You win!")

else:
    print("It's a draw!")
# Out:
# What do you want to choose? Type 0 for Rock, 1 for Paper or 2 for Scissors:  2
# Computer chose: 0
# You lose!

# %% [markdown]
# # 2
# use this statement :- print("Computer chose:")
#        print("game_images[computer_choice])

# %%
import random

#(you must define these)
rock = "🪨Rock"
paper = "📄 Paper"
scissors = "✂️ Scissors"

game_images = [rock, paper, scissors]

# Ask user for input
user_choice = int(input(
    "What do you want to choose? Type 0 for Rock, 1 for Paper or 2 for Scissors: "
))

# Check user input
if user_choice < 0 or user_choice > 2:
    print("You typed an invalid number. You lose!")
else:
    print("You chose:")
    print(game_images[user_choice])

    # Computer choice
    computer_choice = random.randint(0, 2)
    print("Computer chose:")
    print(game_images[computer_choice])

    # Game logic
    if user_choice == 0 and computer_choice == 2:
        print("You win!")
    elif user_choice == 2 and computer_choice == 0:
        print("You lose!")
    elif user_choice > computer_choice:
        print("You win!")
    elif computer_choice > user_choice:
        print("You lose!")
    else:
        print("It's a draw!")
# Out:
# What do you want to choose? Type 0 for Rock, 1 for Paper or 2 for Scissors:  1
# You chose:
# 📄 Paper
# Computer chose:
# 🪨 Rock
# You win!
